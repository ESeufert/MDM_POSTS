# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
import seaborn as sns

# Set random seed for reproducibility
np.random.seed(42)

# Generate synthetic cumulative revenue data for 60 users over 60 days
num_users = 60
num_days = 60
x = np.arange(1, num_days + 1)  # Days from 1 to 60

# Define an underlying revenue growth function (logarithmic growth)
def true_revenue_function(t, a, b):
    return a * np.log(t + 1) + b  # Logarithmic growth function

# Generate true revenue trajectory with parameters
a_true, b_true = 5, 10  # Chosen parameters for revenue growth
true_cumulative_revenue = true_revenue_function(x, a_true, b_true)

# Add one-tailed Gaussian noise at key benchmark points
noise_std = 2.0
benchmark_days = [7, 30, 60]

# Create noisy sample data
user_revenue_data = np.zeros((num_users, num_days))
for i in range(num_users):
    noisy_revenue = true_cumulative_revenue.copy()
    for d in benchmark_days:
        noise = np.abs(np.random.normal(0, noise_std))  # One-tailed (positive) noise
        noisy_revenue[d - 1] += noise  # Ensure non-decreasing revenue
    user_revenue_data[i] = np.maximum.accumulate(noisy_revenue)  # Ensure monotonic increase

# Aggregate the noisy data by averaging across users
noisy_mean_revenue = np.mean(user_revenue_data, axis=0)

# Fit a logarithmic curve to the noisy data
def log_growth(t, a, b):
    return a * np.log(t + 1) + b

# Fit curve to noisy data
params_opt, _ = opt.curve_fit(log_growth, x, noisy_mean_revenue, p0=[5, 10])
a_fit, b_fit = params_opt

# Generate predictions using the fitted model out to day 120
x_future = np.arange(1, 121)  # Predict up to day 120
fitted_revenue = log_growth(x_future, a_fit, b_fit)

# Bootstrap: Resample users, fit curve for each bootstrap, and project to day 120
num_bootstraps = 1000
bootstrap_curves = np.zeros((num_bootstraps, len(x_future)))

for i in range(num_bootstraps):
    sample_indices = np.random.choice(num_users, num_users, replace=True)
    bootstrap_sample = user_revenue_data[sample_indices].mean(axis=0)

    # Fit curve to bootstrap sample
    params_opt, _ = opt.curve_fit(log_growth, x, bootstrap_sample, p0=[5, 10])
    bootstrap_curves[i] = log_growth(x_future, *params_opt)

# Compute confidence intervals
lower_bound = np.percentile(bootstrap_curves, 2.5, axis=0)
upper_bound = np.percentile(bootstrap_curves, 97.5, axis=0)

# Plot results
fig, axs = plt.subplots(3, 1, figsize=(10, 12), sharex=True)

# 1. Raw Noisy Data
axs[0].plot(x, user_revenue_data.T, color="gray", alpha=0.3)
axs[0].plot(x, noisy_mean_revenue, color="blue", label="Mean Noisy Revenue")
axs[0].set_title("Noisy User Cumulative Revenue Data")
axs[0].set_ylabel("Cumulative Revenue")
axs[0].legend()

# 2. Fitted Curve on Noisy Data
axs[1].plot(x, noisy_mean_revenue, color="blue", label="Mean Noisy Revenue")
axs[1].plot(x_future, fitted_revenue, color="red", linestyle="dashed", label="Fitted Curve (Day 120)")
axs[1].set_title("Curve Fit to Noisy Data")
axs[1].set_ylabel("Cumulative Revenue")
axs[1].legend()

# 3. Bootstrapped Confidence Intervals
axs[2].plot(x, noisy_mean_revenue, color="blue", label="Mean Noisy Revenue")
axs[2].plot(x_future, fitted_revenue, color="red", linestyle="dashed", label="Fitted Curve")
axs[2].fill_between(x_future, lower_bound, upper_bound, color="gray", alpha=0.3, label="95% CI")
axs[2].set_title("Bootstrapped Confidence Intervals (1000 samples)")
axs[2].set_xlabel("Days")
axs[2].set_ylabel("Cumulative Revenue")
axs[2].legend()

plt.tight_layout()
plt.show()
